# %% [markdown]
# # Using HuggingFace Model

# %%
from langchain_classic.retrievers.multi_query import MultiQueryRetriever

# %%
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings, HuggingFaceEndpoint, ChatHuggingFace
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_core.documents import Document
import os

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
HF_TOKEN = os.getenv("HF_TOKEN")

# %%
embeddings = HuggingFaceEmbeddings(model_name = "sentence-transformers/all-MiniLM-L6-v2")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 7073.14it/s]

# %%
llm = HuggingFaceEndpoint(
    repo_id="Qwen/Qwen2.5-0.5B-Instruct",
    task="conversational",
    max_new_tokens=256,
    temperature=0.2,
)

# %%
llm_endpoint = HuggingFaceEndpoint(
    repo_id="Qwen/Qwen2.5-0.5B-Instruct",
    task="conversational",
    huggingfacehub_api_token=HF_TOKEN,
    max_new_tokens=256,
    temperature=0.1,
)

llm = ChatHuggingFace(llm=llm_endpoint)

# %%
llm_endpoint = HuggingFaceEndpoint(
    repo_id="HuggingFaceH4/zephyr-7b-beta",
    task="text-generation",
    huggingfacehub_api_token=HF_TOKEN,
    max_new_tokens=256,
    temperature=0.1,
)

llm = ChatHuggingFace(llm=llm_endpoint)

# %%
documents = [
    Document(
        page_content="""
        Transformers use self-attention to understand relationships
        between tokens in a sequence.
        """
    ),

    Document(
        page_content="""
        Self-attention uses Query, Key and Value vectors to calculate
        how much attention each token should give to other tokens.
        """
    ),

    Document(
        page_content="""
        Multi-head attention allows a Transformer to learn different
        types of relationships between tokens simultaneously.
        """
    ),

    Document(
        page_content="""
        Positional encoding provides information about the position
        of tokens because the Transformer does not process tokens
        sequentially like an RNN.
        """
    ),

    Document(
        page_content="""
        Transformers are trained using large datasets and are capable
        of learning contextual relationships between words.
        """
    ),
]

# %%
query="How does attention help Transformers understand text"

# %%
vector_store = FAISS.from_documents(documents = documents, embedding = embeddings)

# %%
base_retriever = vector_store.as_retriever(
    search_kwargs={
        "k": 3
    }
)

# %%
retriever = MultiQueryRetriever.from_llm(
    retriever=base_retriever,
    llm=llm
)

# %%
multi_retriever = MultiQueryRetriever.from_llm(retriever=vector_store.as_retriever(), llm=llm, )

# %%
docs = retriever.invoke(query)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~\anaconda3\envs\venv\Lib\site-packages\huggingface_hub\utils\_http.py:795, in hf_raise_for_status(response, endpoint_name)
#     794 try:
# --> 795     response.raise_for_status()
#     796 except httpx.HTTPStatusError as e:
#
# File ~\anaconda3\envs\venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '400 Bad Request' for url 'https://router.huggingface.co/v1/chat/completions'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/400
#
# The above exception was the direct cause of the following exception:
#
# BadRequestError                           Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 docs = retriever.invoke(query)
#
# File ~\anaconda3\envs\venv\Lib\site-packages\langchain_core\retrievers.py:222, in BaseRetriever.invoke(self, input, config, **kwargs)
#     220 kwargs_ = kwargs if self._expects_other_args else {}
#     221 if self._new_arg_supported:
# --> 222     result = self._get_relevant_documents(
#     223         input, run_manager=run_manager, **kwargs_
#     224     )
#     225 else:
#     226     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~\anaconda3\envs\venv\Lib\site-packages\langchain_classic\retrievers\multi_query.py:179, in MultiQueryRetriever._get_relevant_documents(self, query, run_manager)
#     164 def _get_relevant_documents(
#     165     self,
#     166     query: str,
#     167     *,
#     168     run_manager: CallbackManagerForRetrieverRun,
#     169 ) -> list[Document]:
#     170     """Get relevant documents given a user query.
#     171
#     172     Args:
#    (...)    177         Unique union of relevant documents from all generated queries
#     178     """
# --> 179     queries = self.generate_queries(query, run_manager)
#     180     if self.include_original:
#     181         queries.append(query)
#
# File ~\anaconda3\envs\venv\Lib\site-packages\langchain_classic\retrievers\multi_query.py:199, in MultiQueryRetriever.generate_queries(self, question, run_manager)
#     185 def generate_queries(
#     186     self,
#     187     question: str,
#     188     run_manager: CallbackManagerForRetrieverRun,
#     189 ) -> list[str]:
#     190     """Generate queries based upon user input.
#     191
#     192     Args:
#    (...)    197         List of LLM generated queries that are similar to the user input
#     198     """
# --> 199     response = self.llm_chain.invoke(
#     200         {"question": question},
#     201         config={"callbacks": run_manager.get_child()},
#     202     )
#     203     lines = response["text"] if isinstance(self.llm_chain, LLMChain) else response
#     204     if self.verbose:
#
# File ~\anaconda3\envs\venv\Lib\site-packages\langchain_core\runnables\base.py:3444, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3442                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3443             else:
# -> 3444                 input_ = context.run(step.invoke, input_, config)
#    3445 # finish the root run
#    3446 except BaseException as e:
#
# File ~\anaconda3\envs\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~\anaconda3\envs\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\anaconda3\envs\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~\anaconda3\envs\venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\anaconda3\envs\venv\Lib\site-packages\langchain_huggingface\chat_models\huggingface.py:748, in ChatHuggingFace._generate(self, messages, stop, run_manager, stream, **kwargs)
#     741     message_dicts, params = self._create_message_dicts(messages, stop)
#     742     params = {
#     743         "stop": stop,
#     744         **params,
#     745         **({"stream": stream} if stream is not None else {}),
#     746         **kwargs,
#     747     }
# --> 748     answer = self.llm.client.chat_completion(messages=message_dicts, **params)
#     749     return self._create_chat_result(answer)
#     750 llm_input = self._to_chat_prompt(messages)
#
# File ~\anaconda3\envs\venv\Lib\site-packages\huggingface_hub\inference\_client.py:930, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     902 parameters = {
#     903     "model": payload_model,
#     904     "frequency_penalty": frequency_penalty,
#    (...)    921     **(extra_body or {}),
#     922 }
#     923 request_parameters = provider_helper.prepare_request(
#     924     inputs=messages,
#     925     parameters=parameters,
#    (...)    928     api_key=self.token,
#     929 )
# --> 930 data = self._inner_post(request_parameters, stream=stream)
#     932 if stream:
#     933     return _stream_chat_completion_response(data)  # type: ignore
#
# File ~\anaconda3\envs\venv\Lib\site-packages\huggingface_hub\inference\_client.py:283, in InferenceClient._inner_post(self, request_parameters, stream)
#     271 try:
#     272     response = self.exit_stack.enter_context(
#     273         get_session().stream(
#     274             "POST",
#    (...)    281         )
#     282     )
# --> 283     hf_raise_for_status(response)
#     284     if stream:
#     285         return response.iter_lines()
#
# File ~\anaconda3\envs\venv\Lib\site-packages\huggingface_hub\utils\_http.py:888, in hf_raise_for_status(response, endpoint_name)
#     884 elif response.status_code == 400:
#     885     message = (
#     886         f"\n\nBad request for {endpoint_name} endpoint:" if endpoint_name is not None else "\n\nBad request:"
#     887     )
# --> 888     raise _format(BadRequestError, message, response) from e
#     890 elif response.status_code == 403:
#     891     message = (
#     892         f"\n\n{response.status_code} Forbidden: {error_message}."
#     893         + f"\nCannot access content at: {response.url}."
#     894         + "\nMake sure your token has the correct permissions."
#     895     )
#
# BadRequestError: (Request ID: Root=1-6a7d6d60-0e9bb2c61082d47579cfb6f5;5c330bfe-a067-467f-9722-2362a8baf6d6)
#
# Bad request:
# {'message': "The requested model 'HuggingFaceH4/zephyr-7b-beta' is not supported by any provider you have enabled.", 'type': 'invalid_request_error', 'param': 'model', 'code': 'model_not_supported'}

# %%
results = multi_retriever.invoke(query)

# %% [markdown]
# # Using OpenAI

# %%
from langchain_openai import OpenAIEmbeddings, ChatOpenAI

# %%
embeddings = OpenAIEmbeddings()

# %%
llm = ChatOpenAI(model='gpt-3.5-turbo')

# %%
documents = [
    Document(
        page_content="""
        Transformers use self-attention to understand relationships
        between tokens in a sequence.
        """
    ),

    Document(
        page_content="""
        Self-attention uses Query, Key and Value vectors to calculate
        how much attention each token should give to other tokens.
        """
    ),

    Document(
        page_content="""
        Multi-head attention allows a Transformer to learn different
        types of relationships between tokens simultaneously.
        """
    ),

    Document(
        page_content="""
        Positional encoding provides information about the position
        of tokens because the Transformer does not process tokens
        sequentially like an RNN.
        """
    ),

    Document(
        page_content="""
        Transformers are trained using large datasets and are capable
        of learning contextual relationships between words.
        """
    ),
]

# %%
query="How does attention help Transformers understand text"

# %%
vector_store = FAISS.from_documents(documents = documents, embedding = embeddings)

# %%
multi_retriever = MultiQueryRetriever.from_llm(retriever=vector_store.as_retriever(), llm=llm, )

# %%
results = multi_retriever.invoke(query)

# %%
results

# %%
print('\n MultiQuery Results')
for i in results:
    print("-", i.page_content)
