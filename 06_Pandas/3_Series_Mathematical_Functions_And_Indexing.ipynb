# %% [markdown]
# # `Mathematical Functions and Indexing in Series`
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read Youtube CSV File

# %%
youtube = pd.read_csv(
    "../Datasets/youtube_2025_dataset_202504061614.csv"
)
print(youtube)
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
subs = youtube['Total Subscribers']
print(subs)
# Out:
# 0       8264152
# 1       8768222
# 2       6163386
# 3       4712268
# 4       9592017
#          ...
# 4995    2665835
# 4996     136992
# 4997    2314561
# 4998    6954832
# 4999    6785166
# Name: Total Subscribers, Length: 5000, dtype: int64

# %%
avg = youtube["Avg Video Length (min)"]

# %% [markdown]
# ## Mathematical Functions in Pandas

# %% [markdown]
# ## 1. `sum()`: sum of all values present in the series

# %%
subs.sum()
# Out:
# 25292407967

# %% [markdown]
# ## 2. `product()`: product of all values in the series

# %%
subs.product()
# Out:
# 0

# %% [markdown]
# ## 3. `sort_values()`: sort the series

# %%
subs.sort_values()
# Out:
# 3595       1755
# 3204       2910
# 2470       8649
# 4584       9029
# 2615       9436
#          ...
# 3969    9991900
# 380     9992512
# 1177    9995049
# 3593    9999559
# 1931    9999975
# Name: Total Subscribers, Length: 5000, dtype: int64

# %% [markdown]
# ## 4. `mean()`: provides us average values of the data column

# %%
subs.mean()
# Out:
# 5058481.5934

# %% [markdown]
# ## 5. `median()`: provide the idea about the average of the data itself
# - eg. we need to sort the value in Ascending manner and then the middle value after the sorting the data is median

# %%
subs.median()
# Out:
# 5105967.0

# %% [markdown]
# ## 6. `mode()`: provide us with the idea which value is getting repeated maximum number of times.

# %%
subs.mode()
# Out:
# 0          1755
# 1          2910
# 2          8649
# 3          9029
# 4          9436
#          ...
# 4995    9991900
# 4996    9992512
# 4997    9995049
# 4998    9999559
# 4999    9999975
# Name: Total Subscribers, Length: 5000, dtype: int64

# %% [markdown]
# ## 7. `std()` : stands for Standard Deviation
# - if i need to get the idea that how the vlaues inside the series are distributed from the average or mean value then we can come up with the standard deviation

# %%
avg.std()
# Out:
# 0.8745549483431755

# %% [markdown]
# ## 8. `variance()`: provide the insight about the distribution of the data from the mean value and variance is the square of the standard deviation.
# - standard_deviation = |mean - v_1| + |mean - v_2|..../ total count of values
# - variance = std**2

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg.var()
# Out:
# 0.7648463576715343

# %% [markdown]
# ## 9. `min()`: minimum value in the Series

# %%
avg.min()
# Out:
# 19.1

# %%
subs.min()
# Out:
# 1755

# %% [markdown]
# ## 10. `max()` : maximum value in the Series

# %%
avg.max()
# Out:
# 28.9

# %%
subs.max()
# Out:
# 9999975

# %% [markdown]
# ## 11. `describe()` : provide the idea about the summary of the important mathematical calculations for the data  (VV Important)
# - min: minimum value
# - max: maximum value
# - mean: average value
# - std: standard deviation
# - 25%: 25% of the values out of my all values are less than this specific value.
# - 50%: 50% of the values out of my all values are less than this specific value.
# - 75%: 75% of the values out of my all values are less than this specific value.
# - count: total number of rows in the column
#
# eg. JEE mains : 25% --> my score in JEE Mains was greater than 25% of the total applicants who applied in JEE

# %%
avg.describe()
# Out:
# count    5000.000000
# mean       24.004540
# std         0.874555
# min        19.100000
# 25%        23.500000
# 50%        24.000000
# 75%        24.500000
# max        28.900000
# Name: Avg Video Length (min), dtype: float64

# %%
subs.describe()
# Out:
# count    5.000000e+03
# mean     5.058482e+06
# std      2.890895e+06
# min      1.755000e+03
# 25%      2.547991e+06
# 50%      5.105967e+06
# 75%      7.541903e+06
# max      9.999975e+06
# Name: Total Subscribers, dtype: float64

# %% [markdown]
# ---
#
# # `Indexing in Series`
#
# ---

# %% [markdown]
# ## `Indexing`
# To have the access over the certain value or values in the Series.
#
# Indexing is done by
# 1. Positive Indexing ( just like list in Python ): Start from 0 to forward direction
# 2. No Negative Indexing in Series

# %%
print(avg[0])
print(avg[1])
# Out:
# 24.8
# 22.9

# %%
# print(avg[-1]) # ValueError: -1 is not in range

# %% [markdown]
# ## `Slicing` :
# - In Series, wew can get the certain values over a given specific range and we can do it using
# - Syntax: [initial_value, final_value + 1]

# %%
avg[7:17]
# Out:
# 7     25.6
# 8     23.1
# 9     24.2
# 10    22.9
# 11    25.4
# 12    26.9
# 13    23.4
# 14    24.1
# 15    24.9
# 16    24.7
# Name: Avg Video Length (min), dtype: float64

# %% [markdown]
# I want the values skipped as a certain values

# %%
avg[2:21:2] # [start, end, skip]
# Out:
# 2     24.0
# 4     24.6
# 6     23.2
# 8     23.1
# 10    22.9
# 12    26.9
# 14    24.1
# 16    24.7
# 18    23.6
# 20    24.8
# Name: Avg Video Length (min), dtype: float64

# %% [markdown]
# ### Reverse values in a Series

# %%
avg[::-1]
# Out:
# 4999    25.2
# 4998    24.5
# 4997    25.2
# 4996    26.3
# 4995    22.0
#         ...
# 4       24.6
# 3       24.6
# 2       24.0
# 1       22.9
# 0       24.8
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## `Fancy Indexing`: if i want the specific values from the series then we can go with fancy indexing

# %%
# avg[2,4,9,10,19] # KeyError: '
# key of type tuple not found and not a MultiIndex

# %%
avg[[2,4,9,10,19]]
# Out:
# 2     24.0
# 4     24.6
# 9     24.2
# 10    22.9
# 19    24.1
# Name: Avg Video Length (min), dtype: float64

# %%
avg[[5, 500, 1500, 4800]]
# Out:
# 5       24.2
# 500     19.1
# 1500    24.6
# 4800    24.4
# Name: Avg Video Length (min), dtype: float64

# %% [markdown]
# ## `Indexing with Labels`: a series which is consisting of Labels as the index or custom index, then for this data we can retreive the info using that custom value or index

# %%
youtube
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
print(youtube.columns)
# Out:
# Index(['Channel Name', 'Youtuber Name', 'Total Videos', 'Best Video',
#        'Avg Video Length (min)', 'Total Subscribers', 'Members Count',
#        'AI Generated Content (%)', 'Neural Interface Compatible',
#        'Metaverse Integration Level', 'Quantum Computing Topics',
#        'Holographic Content Rating', 'Engagement Score',
#        'Content Value Index'],
#       dtype='str')

# %%
youtube['Youtuber Name']
# Out:
# 0               Eric Patel
# 1       Cynthia Harrington
# 2            Amanda Walker
# 3        Jessica Nelson MD
# 4          Matthew Sherman
#                ...
# 4995         Jasmine Smith
# 4996        John Rasmussen
# 4997            Lisa Burke
# 4998            Steve Diaz
# 4999           Austin Tate
# Name: Youtuber Name, Length: 5000, dtype: str

# %% [markdown]
# ## Editing Series ( Bring the changes into the values stored inside the Series)
#
# - Using Indexing : df[0] = 65 --> changing the original value at index 0 to 65

# %%
youtube['Cynthia Harrington']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\arunk\anaconda3\envs\genai_env\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cynthia Harrington'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ...

# %% [markdown]
# ## If Indexing doesn't exist

# %%
youtube['Arun Jawlia']=78

# %% [markdown]
# ## Slicing in Series : df[2:7] = 100 : 100 values will be associated for index 2 to 6

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg[1:5] = 28

# %%
avg
# Out:
# 0       24.8
# 1       28.0
# 2       28.0
# 3       28.0
# 4       28.0
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## Fancing Indexing for datafram : df[2,4,8] = [45, 99, 89]

# %%
avg[[4,4998,4996,0]]=[25,21,20,24]

# %%
avg
# Out:
# 0       24.0
# 1       28.0
# 2       28.0
# 3       28.0
# 4       25.0
#         ...
# 4995    22.0
# 4996    20.0
# 4997    25.2
# 4998    21.0
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## `Index Labeling`

# %%
youtube[['Eric Patel', 'Jessica Nelson MD']]= [2000,498,84848]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9224\2608339022.py in ?()
# ----> 1 youtube[['Eric Patel', 'Jessica Nelson MD']]= [2000,498,84848]
#
# c:\Users\arunk\anaconda3\envs\genai_env\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4656
#    4657         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4658             self._setitem_frame(key, value)
#    4659         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4660             self._setitem_array(key, value)
#    4661         elif isinstance(value, DataFrame):
#    4662             self._set_item_frame_value(key, value)
#    4663         elif (
#
# c:\Users\arunk\anaconda3\envs\genai_env\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4712             value = DataFrame(value).values
# ...
