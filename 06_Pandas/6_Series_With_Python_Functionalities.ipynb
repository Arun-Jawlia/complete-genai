# %% [markdown]
# # Series with Python Functinalitites
# ---

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Datasets/youtube_2025_dataset_202504061614.csv')

# %%
df_one = pd.read_csv("../Datasets/youtube_2025_dataset_one_column.csv").squeeze("columns")
dataframe = pd.read_csv('../Datasets/youtube_2025_dataset_two_columns.csv', index_col='Youtuber Name').squeeze('columns')

# %%
avg = df['Avg Video Length (min)']

# %% [markdown]
# ## 1. `len`    : provide the number of elements present in the series.

# %%
len(dataframe)
# Out:
# 5000

# %% [markdown]
# ## 2. `type`: provides the idea about the data type of series.

# %%
type(dataframe)
# Out:
# pandas.Series

# %% [markdown]
# ## 2. `dir` : provides idea about the all of the methods and attributes associated with the Series.

# %%
dir(dataframe)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
# ...

# %% [markdown]
# ## 4.  `sorted`: sort the values in ascending order

# %%
sorted(avg)
# Out:
# [19.1,
#  19.3,
#  19.9,
#  20.6,
#  20.7,
#  20.9,
#  20.9,
#  20.9,
#  21.0,
#  21.1,
#  21.2,
#  21.3,
#  21.3,
#  21.3,
#  21.3,
#  21.3,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.4,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.5,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.6,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.7,
#  21.8,
#  21.8,
#  21.8,
#  21.8,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  21.9,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.0,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.1,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
#  22.2,
# ...

# %% [markdown]
# Note:
# 1. Package Function: object.function_name()
# 2. Built in Functionality: funcation_name(object)

# %% [markdown]
# ## 5. `max()`: calculate the max value in the Series

# %%
max(avg)
# Out:
# 28.9

# %% [markdown]
# ## 6. `min()`: calculate the min values in the Series

# %%
min(avg)
# Out:
# 19.1

# %% [markdown]
# ## 7. `Type Conversion` in Series
# - convert the data type of the given Series into another Data type
# - Series --> list --> list(Series)
# - Series --> dict --> dict(Series)

# %%
type(avg)
# Out:
# pandas.Series

# %%
list_type = list(avg)
print(type(list_type))
# Out:
# <class 'list'>

# %%
print(type(dataframe))
dict_type = dict(dataframe)
print(type(dict_type))
# Out:
# <class 'pandas.Series'>
# <class 'dict'>

# %% [markdown]
# ## 8. `Membership Operators`
# - `in` operator: checks whether if a value is in the series or not
# - checks for the element in the index or label of the series.
# - eg. df.values() to check that whether if a member is of series or not

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
"Arun Jawlia" in dataframe
# Out:
# False

# %%
'Cynthia Harrington' in dataframe
# Out:
# True

# %%
128 in dataframe.values
# Out:
# True

# %% [markdown]
# ## 9. `Looping` : for loop for iterating over the items of the Series and for the index iterating we can gog with Series_name.index

# %%
for i in avg:
    print(i)
# Out:
# 24.8
# 22.9
# 24.0
# 24.6
# 24.6
# 24.2
# 23.2
# 25.6
# 23.1
# 24.2
# 22.9
# 25.4
# 26.9
# 23.4
# 24.1
# 24.9
# 24.7
# 24.8
# 23.6
# 24.1
# 24.8
# 24.2
# 23.2
# 23.4
# 24.9
# 24.2
# 23.3
# 23.6
# 25.5
# 25.2
# 24.6
# 24.9
# 23.7
# 23.2
# 24.1
# 24.0
# 24.3
# 23.8
# 23.6
# 24.9
# 24.0
# 23.4
# 23.3
# 23.9
# 23.8
# 24.5
# 22.9
# 23.1
# 23.4
# 23.9
# 25.6
# 23.3
# 24.6
# 23.9
# 23.1
# 24.9
# 23.0
# 24.1
# 24.0
# 23.4
# 24.9
# 25.9
# 24.7
# 23.5
# 24.0
# 25.8
# 23.7
# 23.9
# 23.8
# 24.0
# 24.0
# 24.1
# 25.1
# 24.3
# 23.9
# 23.5
# 24.4
# 22.9
# 23.1
# 25.1
# 24.8
# 23.7
# 24.1
# 24.4
# 23.9
# 22.1
# 23.7
# 24.5
# 24.2
# 23.8
# 24.2
# 22.8
# 24.9
# 24.4
# 27.0
# 23.2
# 24.5
# 26.1
# 23.4
# 23.4
# 24.1
# 22.3
# 24.1
# 24.3
# 24.1
# 24.8
# 23.8
# 23.7
# 24.2
# 24.4
# 23.7
# 24.2
# 23.1
# 23.4
# 23.9
# 23.9
# 23.6
# 23.4
# 25.6
# 23.3
# 24.1
# 23.4
# 24.7
# 24.8
# 23.9
# 24.4
# 25.1
# 22.9
# 24.6
# 24.4
# 25.0
# 23.7
# 23.6
# 24.7
# 26.0
# 22.8
# 23.6
# 22.8
# 23.2
# 22.9
# 22.4
# 24.3
# ...

# %%
for i in dataframe.index:
    print(i)
# Out:
# Eric Patel
# Cynthia Harrington
# Amanda Walker
# Jessica Nelson MD
# Matthew Sherman
# Anna Berry
# Richard Arnold
# Stephanie Potter
# Teresa Aguirre
# Anne Adkins
# David Clark
# Kathleen Weeks
# Melissa Kennedy
# Kimberly Brown
# Jennifer Martinez
# Elizabeth Wright
# Elijah Ruiz
# Thomas Roberts
# Julian Gutierrez
# Sheila Rivera
# Crystal Vargas
# Kevin Marquez
# Gregory Norman
# Jason Hall
# Jacob Patterson
# Daniel Costa
# Vincent Graves
# Anthony Huynh
# Michelle Rogers
# Alison Scott
# Sherry Reed
# Mr. James Montgomery
# Leah Moss
# Shelby Pace
# Tracie Hogan
# Mrs. Katelyn Soto
# Monica Henry
# Kevin Martinez MD
# Kathryn Harris
# Allison Phillips
# Maxwell Anderson
# Terry Meyer
# Wanda Hernandez
# Brenda Boyd
# Anna Frank
# Heather Jefferson
# Michelle Martinez
# Sara Mack
# Christopher Taylor
# Larry Zimmerman
# David Craig
# Antonio Reilly
# Oscar Gallegos
# William White
# Brittany Dickerson
# Jennifer Kane
# Shannon Rodriguez
# Sarah Little
# Timothy Page
# ...

# %% [markdown]
# ## 10. `Arithmetic Operator`:
# - dataframe + 100

# %%
dataframe
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
added = dataframe + 100
substracted = dataframe - 50
multiplied = dataframe * 200
divided = dataframe / 100

# %%
added
# Out:
# Youtuber Name
# Eric Patel            168
# Cynthia Harrington    228
# Amanda Walker         382
# Jessica Nelson MD     402
# Matthew Sherman       229
#                      ...
# Jasmine Smith         206
# John Rasmussen        230
# Lisa Burke            279
# Steve Diaz            282
# Austin Tate           192
# Name: Total Videos, Length: 5000, dtype: int64

# %%
substracted
# Out:
# Youtuber Name
# Eric Patel             18
# Cynthia Harrington     78
# Amanda Walker         232
# Jessica Nelson MD     252
# Matthew Sherman        79
#                      ...
# Jasmine Smith          56
# John Rasmussen         80
# Lisa Burke            129
# Steve Diaz            132
# Austin Tate            42
# Name: Total Videos, Length: 5000, dtype: int64

# %%
multiplied
# Out:
# Youtuber Name
# Eric Patel            13600
# Cynthia Harrington    25600
# Amanda Walker         56400
# Jessica Nelson MD     60400
# Matthew Sherman       25800
#                       ...
# Jasmine Smith         21200
# John Rasmussen        26000
# Lisa Burke            35800
# Steve Diaz            36400
# Austin Tate           18400
# Name: Total Videos, Length: 5000, dtype: int64

# %%
divided
# Out:
# Youtuber Name
# Eric Patel            0.68
# Cynthia Harrington    1.28
# Amanda Walker         2.82
# Jessica Nelson MD     3.02
# Matthew Sherman       1.29
#                       ...
# Jasmine Smith         1.06
# John Rasmussen        1.30
# Lisa Burke            1.79
# Steve Diaz            1.82
# Austin Tate           0.92
# Name: Total Videos, Length: 5000, dtype: float64

# %% [markdown]
# ## 12. `Relational Operator` in Series

# %%
200 > dataframe
# Out:
# Youtuber Name
# Eric Patel             True
# Cynthia Harrington     True
# Amanda Walker         False
# Jessica Nelson MD     False
# Matthew Sherman        True
#                       ...
# Jasmine Smith          True
# John Rasmussen         True
# Lisa Burke             True
# Steve Diaz             True
# Austin Tate            True
# Name: Total Videos, Length: 5000, dtype: bool

# %%
dataframe <= 168
# Out:
# Youtuber Name
# Eric Patel             True
# Cynthia Harrington     True
# Amanda Walker         False
# Jessica Nelson MD     False
# Matthew Sherman        True
#                       ...
# Jasmine Smith          True
# John Rasmussen         True
# Lisa Burke            False
# Steve Diaz            False
# Austin Tate            True
# Name: Total Videos, Length: 5000, dtype: bool

# %% [markdown]
# ## 13. `Boolean Indexing` in Series
# - to perform the Important Analysis on the column values, where in a specific index values if it missing a condition that we get True over their else we get False
# - Return --> True --> Condition is True
# - Return --> False --> Condition is Not True

# %%
avg
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
# which youtube are having average video lenght greater than 24 minutes

avg > 24
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 4995    False
# 4996     True
# 4997     True
# 4998     True
# 4999     True
# Name: Avg Video Length (min), Length: 5000, dtype: bool

# %%
# only get the youtube having 24 minutes average length
avg[avg > 24]
# avg[avg > 24].size
# Out:
# 0       24.8
# 3       24.6
# 4       24.6
# 5       24.2
# 7       25.6
#         ...
# 4994    24.8
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 2381, dtype: float64

# %%
dataframe[dataframe > 120]
# Out:
# Youtuber Name
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
# Richard Arnold        494
#                      ...
# Howard Phelps         126
# Sharon Graham         231
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Name: Total Videos, Length: 4175, dtype: int64

# %%
dataframe[dataframe > 300]
# Out:
# Youtuber Name
# Jessica Nelson MD    302
# Richard Arnold       494
# Teresa Aguirre       316
# Jennifer Martinez    383
# Elijah Ruiz          373
#                     ...
# Carlos Howell        477
# Kevin Arellano       305
# Michelle Knight      386
# Donna Lane           417
# Kelly Russell        374
# Name: Total Videos, Length: 2228, dtype: int64

# %% [markdown]
# ## 14. `Plotting Graph in Pandas`
# - for plotting graphs in Pandas, we require `plot()` function
# - kind --> it decides what kind of graph you want to plot like bar, pipe
# - Syntax: df.plot()

# %%
avg.plot()
# Out:
# <Axes: >

# %%
dataframe.sort_values(ascending=False).head(15).plot(kind='bar')
# Out:
# <Axes: xlabel='Youtuber Name'>

# %%
dataframe.sort_values(ascending=False).sample(15).plot(kind='bar')
# Out:
# <Axes: xlabel='Youtuber Name'>

# %%
dataframe.sort_values(ascending=False).sample(15).plot(kind='pie')
# Out:
# <Axes: >
