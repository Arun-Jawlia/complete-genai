# %% [markdown]
# # `Real World Datasets in Series`
# ---

# %%
import pandas as pd

# %% [markdown]
# ## `read_csv()`
# - this function reads the content from the csv file in pandas
# - We can perform operations or effective analysis on the data

# %%
df = pd.read_csv('../Datasets/youtube_2025_dataset_202504061614.csv')

# %%
df
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %% [markdown]
# ## `Dataframe`:
# - combination of Multiple Series( Columns )

# %% [markdown]
# ### `squeeze` : make sure that the data should be in series format

# %%
# without squeeze, type is dataframe
df_one = pd.read_csv("../Datasets/youtube_2025_dataset_one_column.csv")
print(df)
print("\n")
print(type(df_one))
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
# With Squeese, type is Series
df_one = pd.read_csv("../Datasets/youtube_2025_dataset_one_column.csv").squeeze("columns")
print(df_one)
print("\n")
print(type(df_one))
# Out:
# 0                   Smith-Ross Labs
# 1                  Sandoval PLC Hub
# 2       Jones, Moore and Ho Network
# 3              Mitchell-Hooper Labs
# 4                Wilson LLC Studios
#                    ...
# 4995          Flores-Daniel Studios
# 4996       Spencer and Sons Studios
# 4997         Obrien-Roberts Studios
# 4998                   King Ltd Hub
# 4999              Henry Ltd Studios
# Name: Channel Name, Length: 5000, dtype: str
#
#
# <class 'pandas.Series'>

# %% [markdown]
# ### Two Columns

# %%
pd.read_csv("../Datasets/youtube_2025_dataset_two_columns.csv")
# Out:
#            Youtuber Name  Total Videos
# 0             Eric Patel            68
# 1     Cynthia Harrington           128
# 2          Amanda Walker           282
# 3      Jessica Nelson MD           302
# 4        Matthew Sherman           129
# ...                  ...           ...
# 4995       Jasmine Smith           106
# 4996      John Rasmussen           130
# 4997          Lisa Burke           179
# 4998          Steve Diaz           182
# 4999         Austin Tate            92
#
# [5000 rows x 2 columns]

# %% [markdown]
# ## `index_col` : specific column you want to refer it to as your index column

# %%
df_two = pd.read_csv('../Datasets/youtube_2025_dataset_two_columns.csv', index_col='Youtuber Name').squeeze('columns')
print(df_two)
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %% [markdown]
# # `Attribute in Series`

# %% [markdown]
# ## 1. `.values` : representing only the values of the given series

# %%
df_one.values # values = youtube name
# Out:
# <ArrowStringArray>
# [                    'Smith-Ross Labs',                    'Sandoval PLC Hub',
#          'Jones, Moore and Ho Network',                'Mitchell-Hooper Labs',
#                   'Wilson LLC Studios',                   'Myers Ltd Network',
#                    'Huber Inc Network',              'Baxter-Collins Studios',
#                    'Morrow-Abbott Hub',               'Jackson Group Network',
#  ...
#                      'Cole-Sharp Labs', 'Sherman, Mcgee and Phillips Studios',
#                       'Baker-Hill Hub',    'Francis, Davis and Jones Network',
#      'Whitaker, Horn and Escobar Labs',               'Flores-Daniel Studios',
#             'Spencer and Sons Studios',              'Obrien-Roberts Studios',
#                         'King Ltd Hub',                   'Henry Ltd Studios']
# Length: 5000, dtype: str

# %%
df_two.values # value = total videos of youtube
# Out:
# array([ 68, 128, 282, ..., 179, 182,  92], dtype=int64)

# %% [markdown]
# ## 2. `.index`: return only the index values from the given column

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5000, step=1)

# %%
df_one.index
# Out:
# RangeIndex(start=0, stop=5000, step=1)

# %%
df_two.index
# Out:
# Index(['Eric Patel', 'Cynthia Harrington', 'Amanda Walker',
#        'Jessica Nelson MD', 'Matthew Sherman', 'Anna Berry', 'Richard Arnold',
#        'Stephanie Potter', 'Teresa Aguirre', 'Anne Adkins',
#        ...
#        'Erin Bradley', 'Brooke Perez', 'Nicholas Jordan', 'Howard Phelps',
#        'Sharon Graham', 'Jasmine Smith', 'John Rasmussen', 'Lisa Burke',
#        'Steve Diaz', 'Austin Tate'],
#       dtype='str', name='Youtuber Name', length=5000)

# %% [markdown]
# ## 3. `dtype`: provides the idea about the data type of the values that you are storing

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19064\1115469300.py in ?()
# ----> 1 df.dtype
#
# c:\Users\arunk\anaconda3\envs\genai_env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df_one.dtype
# Out:
# <StringDtype(na_value=nan)>

# %%
df_two.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## 4. `.astype`: change the data size

# %%
print(df_two)
print(df_two.dtype)
new_astype = df_two.astype('int32')
print("\n")
print(new_astype)
print(new_astype.dtype)
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64
# int64
#
#
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int32
# int32

# %% [markdown]
# ## 5. `size`: provide the idea about the total numbers of rows in dataset

# %%
print(df)
print('\n')
print(df.size)
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %% [markdown]
# ## 6. `shape`: provide the idea about the rows and column in the dataset

# %%
print(df.shape)
print(df_one.shape)
print(df_two.shape)
# Out:
# (5000, 14)
# (5000,)
# (5000,)

# %% [markdown]
# ## 7. `ndim`: provide the idea about the dimension of the given dataset

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ## 8. `name`: provides the idea about the name of the series

# %% [markdown]
# ## 9. `is_unique`: provides us the idea about whether the uniques values are their or not inside the column

# %%
df_two
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
df_two.name
# Out:
# 'Total Videos'

# %%
df_two.is_unique # False: not unique value
# Out:
# False

# %%
pd.Series([11,2,3,4]).is_unique
# Out:
# True

# %% [markdown]
# ---
# # `Series Methods`
# ---

# %% [markdown]
# ## 1. `head()`
# - provides the Top Preview of Data as the Top 5 Rows of the Dataframe or Series
# - Quite helpful with providing the preview of the dataset and if want to  preview Top 10 rows then pass 10 as an argument to head(10) function

# %%
df.head()
# Out:
#                   Channel Name       Youtuber Name  Total Videos  \
# 0              Smith-Ross Labs          Eric Patel            68
# 1             Sandoval PLC Hub  Cynthia Harrington           128
# 2  Jones, Moore and Ho Network       Amanda Walker           282
# 3         Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4           Wilson LLC Studios     Matthew Sherman           129
#
#                            Best Video  Avg Video Length (min)  \
# 0           VR Challenge: Review 2023                    24.8
# 1  Nanotech Simulation: Analysis 2024                    22.9
# 2  Metaverse Interface: Analysis 2024                    24.0
# 3            VR Protocol: Review 2023                    24.6
# 4    Nanotech Simulation: Review 2024                    24.6
#
#    Total Subscribers  Members Count  AI Generated Content (%)  \
# 0            8264152         303319                         9
# 1            8768222         384629                        62
# ...

# %%
df_two.head()
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
# Name: Total Videos, dtype: int64

# %%
df_two.head(1)
# Out:
# Youtuber Name
# Eric Patel    68
# Name: Total Videos, dtype: int64

# %% [markdown]
# ## 2. `tail()`
# - provides the Botom Preview of Data as the Bottom 5 Rows of the Dataframe or Series
# - Quite helpful with providing the preview of the dataset and if want to  preview Bottom 10 rows then pass 10 as an argument to head(10) function

# %%
df_two
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
df_two.tail()
# Out:
# Youtuber Name
# Jasmine Smith     106
# John Rasmussen    130
# Lisa Burke        179
# Steve Diaz        182
# Austin Tate        92
# Name: Total Videos, dtype: int64

# %% [markdown]
# ## 3. `sample()`:
# - provide any custom or random row from the dataset for us to preview it

# %%
df_two.sample()
# Out:
# Youtuber Name
# Laurie Singh    349
# Name: Total Videos, dtype: int64

# %%
df_two.sample(5) # any 5 random rows from data set
# Out:
# Youtuber Name
# Bobby Martin        113
# Andrew Howard       470
# Julie Thompson       67
# Adrian Rodriguez    137
# Stanley Kennedy     487
# Name: Total Videos, dtype: int64

# %% [markdown]
# ## 4. `value_count()`
# - provide the idea about the count of the values ( categorical values )
# - if i am having a column where the categorical value count I want then use value_count()
# - eg. any name repeated, show how many time repeated

# %%
youtube = pd.read_csv('../Datasets/youtube_2025_dataset_202504061614.csv')
print(youtube)
# Out:
#                      Channel Name       Youtuber Name  Total Videos  \
# 0                 Smith-Ross Labs          Eric Patel            68
# 1                Sandoval PLC Hub  Cynthia Harrington           128
# 2     Jones, Moore and Ho Network       Amanda Walker           282
# 3            Mitchell-Hooper Labs   Jessica Nelson MD           302
# 4              Wilson LLC Studios     Matthew Sherman           129
# ...                           ...                 ...           ...
# 4995        Flores-Daniel Studios       Jasmine Smith           106
# 4996     Spencer and Sons Studios      John Rasmussen           130
# 4997       Obrien-Roberts Studios          Lisa Burke           179
# 4998                 King Ltd Hub          Steve Diaz           182
# 4999            Henry Ltd Studios         Austin Tate            92
#
#                               Best Video  Avg Video Length (min)  \
# 0              VR Challenge: Review 2023                    24.8
# ...

# %%
yt_name = youtube['Youtuber Name']
print(yt_name)
print('\n')
print(yt_name.value_counts())
# Out:
# 0               Eric Patel
# 1       Cynthia Harrington
# 2            Amanda Walker
# 3        Jessica Nelson MD
# 4          Matthew Sherman
#                ...
# 4995         Jasmine Smith
# 4996        John Rasmussen
# 4997            Lisa Burke
# 4998            Steve Diaz
# 4999           Austin Tate
# Name: Youtuber Name, Length: 5000, dtype: str
#
#
# Youtuber Name
# Jennifer Smith    4
# Michael Smith     4
# James Miller      4
# Stephen Taylor    3
# David Williams    3
#                  ..
# Sharon Graham     1
# John Rasmussen    1
# Lisa Burke        1
# Steve Diaz        1
# Austin Tate       1
# Name: count, Length: 4831, dtype: int64

# %%
avg = youtube['Avg Video Length (min)']
print(avg)
print(type(avg))
print("\n")
avg.value_counts() # show how many times repeated a value in dataset
# Out:
# 0       24.8
# 1       22.9
# 2       24.0
# 3       24.6
# 4       24.6
#         ...
# 4995    22.0
# 4996    26.3
# 4997    25.2
# 4998    24.5
# 4999    25.2
# Name: Avg Video Length (min), Length: 5000, dtype: float64
# <class 'pandas.Series'>
# Avg Video Length (min)
# 24.1    276
# 23.8    264
# 23.9    256
# 24.2    253
# 24.0    251
#        ...
# 19.9      1
# 27.3      1
# 28.0      1
# 21.0      1
# 20.7      1
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# ## 5. `sort_values()`:
# - sort the values in ascending manner
# - useful for the numerical column
# - sort the value in descending manner , passing ascending = False in the sort_values(ascending=False)

# %%
avg.sort_values() # youtube video length in ascending manner
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg.sort_values(ascending=False)
# Out:
# 361     28.9
# 1467    28.4
# 364     28.3
# 925     28.1
# 2748    28.0
#         ...
# 3704    20.7
# 171     20.6
# 1713    19.9
# 451     19.3
# 500     19.1
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ### `Method Channing` :
# - use multiple methods together to get the required value in a way the first method's output  will be input for the next one and so on..

# %%
avg.sort_values(ascending=False).head(1)
# Out:
# 361    28.9
# Name: Avg Video Length (min), dtype: float64

# %%
avg.sort_values(ascending=False).head(1).values[0]
# Out:
# 28.9

# %% [markdown]
# ## 5. `inplace` : in order to change the data permanent

# %%
avg.sort_values(ascending=False)
# Out:
# 361     28.9
# 1467    28.4
# 364     28.3
# 925     28.1
# 2748    28.0
#         ...
# 3704    20.7
# 171     20.6
# 1713    19.9
# 451     19.3
# 500     19.1
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %%
avg_copy = avg.copy()

# %%
avg_copy.sort_values(inplace=True) # now it is permanent change

# %%
avg_copy
# Out:
# 500     19.1
# 451     19.3
# 1713    19.9
# 171     20.6
# 3704    20.7
#         ...
# 2748    28.0
# 925     28.1
# 364     28.3
# 1467    28.4
# 361     28.9
# Name: Avg Video Length (min), Length: 5000, dtype: float64

# %% [markdown]
# ## 6. `sort_index`: sorts the index in descending manner

# %%
df_two
# Out:
# Youtuber Name
# Eric Patel             68
# Cynthia Harrington    128
# Amanda Walker         282
# Jessica Nelson MD     302
# Matthew Sherman       129
#                      ...
# Jasmine Smith         106
# John Rasmussen        130
# Lisa Burke            179
# Steve Diaz            182
# Austin Tate            92
# Name: Total Videos, Length: 5000, dtype: int64

# %%
df_two.sort_index()
# Out:
# Youtuber Name
# Aaron Archer        136
# Aaron Bishop        151
# Aaron Brown          51
# Aaron Burns         314
# Aaron Carrillo      210
#                    ...
# Zachary Phillips    478
# Zachary Russell      81
# Zachary Shelton     446
# Zoe Peterson         78
# Zoe Smith            83
# Name: Total Videos, Length: 5000, dtype: int64
