# %% [markdown]
# # `What is Python Language`
# ---
# - Python is a type of programming language which we can use for communicating with computers or technology
# - used in Artificial Intelligence, Machine Learning, Neural Networks and many other advanced fields of Computer Science.
# - high-level, general-purpose & interpreted programming language.
# - dynamically typed and garbage-collected, and supports multiple programming paradigms like structured(particularly, procedural,) object-oriented,and functional programming language

# %% [markdown]
# ## Syntax for Python language
# - Syntax refers to the set of rules that defines the combination of symbols that are consider to be correctly structured programs in a language.

# %% [markdown]
# ## Semantics of Python Language

# %% [markdown]
# Semantics of Python language refers to the meaning or interpretations of symbols, characters and commands in a language. It is about what the code is supposed to do when it run.

# %% [markdown]
# # Python Syntax Rules
# - Python is case-sensitive

# %%
name = 'Amit'
Name = 'Amit'
name == Name
print("hello world")
