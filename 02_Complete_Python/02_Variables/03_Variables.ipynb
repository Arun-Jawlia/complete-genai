# %% [markdown]
# # Variables
# ---

# %% [markdown]
# ### Variables are the element in python that can be used for storing data into it or values into it or they can be referred as containers as well.
# ### Variables ar per their name, data can vary that we are going to store inot it and once we have declared a variables we can vary the value stored in it.
#
# ## or
#
# ### Variable in Programming is a named storage location that holds a value or data.

# %%
age = 28
name = 'Arun Jawlia'
is_true = True
height = 5.8

# age and name act like a variables

# %%
age
# Out:
# 28

# %%
print(age, name, height, is_true)
# Out:
# 28 Arun Jawlia 5.8 True

# %% [markdown]
# ## Print() --> print function is being used to represent the value that we are going to pass inside it.
# ---

# %%
print("Variable is: container to store data", "name", name)
# Out:
# Variable is: container to store data name Arun Jawlia

# %% [markdown]
# ---
# ## Comments in Python
# - Comments - statements in a program that we dont want the interpreter to execute
# - Syntax of comment : use hash ( # ) before the line start
#
# - Interpreter --> execute the code line by line in python language
# - Compiler --> executres the code completely

# %%
# Hello Everything, this is syntax of commenting

# %%
print("hello world") # this is comment to show what is print work
# Out:
# hello world

# %% [markdown]
# ---
# # Variable Naming Convention
# - must be descriptive
# - must be start with letter or underscore ( _ ) and can contain letter , number and underscore ( _name, _Age, Address, address, a1234bcde )
# - case sensitve ( name is not equal Name) name != Name

# %%
# Check what type of variable
age = 27
is_Boolean = True
is_float = 0.6
is_string = 'abvljkdg'

print("type of age" ,type(age))
print("type of is_true", type(is_Boolean))
print('type of float', type(is_float))
print("type of String", type(is_string))
# Out:
# type of age <class 'int'>
# type of is_true <class 'bool'>
# type of float <class 'float'>
# type of String <class 'str'>

# %% [markdown]
# ---
# # Type Casting - Convert from one data type to another
#
# Every Type casting is not possible
# - int --> str
# - str  =/= int

# %%
age = 57
print(type(age))
age = str(age)
print(type(age))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# # input()
# input() function can take the input from the user side and then can store that input into a variable.

# %%
name = input('Enter your name')
print("Your Name",name)
# Out:
# Your Name

# %% [markdown]
# ### input function only takes the input in a string format until and unless we are not going to explicitly tkae the input in integer or other format.

# %%
age = float(input('Enter your age: '))
print(age, type(age))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 age = float(input('Enter your age: '))
#       2 print(age, type(age))
#
# ValueError: could not convert string to float: ''

# %%
value = bool(input("Enter a value 0 or 1: "))
print(value, type(value))

# %%
## Building a Simple Calculator

value_1 = int(input("Enter your first value:"))
value_2 = int(input("Enter your second value:"))

print(f"Addtion of {value_1} and {value_2} ", value_1 + value_2)
print(f"Substract of {value_1} and {value_2} ", value_1 - value_2)
print(f"Multiply of {value_1} and {value_2} ", value_1 * value_2)
print(f"Division of {value_1} and {value_2} ", value_1 / value_2)
