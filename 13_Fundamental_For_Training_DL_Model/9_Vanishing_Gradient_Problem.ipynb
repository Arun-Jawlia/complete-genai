# %% [markdown]
# ---
# # `Vanishing Gradient Problem in Neural Network`
# ---

# %% [markdown]
# It happend when Gradient become so small that earlier layer stops erarning.
#
# The network forget how to learn in the beginnings layers
#
# Real life analogy:
# - Imagine 10 people standing in a line 1 last person whipser  loudly and message goes backward
