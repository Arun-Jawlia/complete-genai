# %% [markdown]
# # Task 1: Getting starting with AstraDB (Datastax)

# %% [markdown]
# 1. Created DataStax AstraDB Account
# 2. Created Vector Database
# 3. Generated Application token and DB endpoint
