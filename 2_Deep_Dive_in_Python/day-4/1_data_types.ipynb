# %% [markdown]
# # Data Types

# %% [markdown]
# ---

# %% [markdown]
# ### Data types are classification of the data that tells the compiler or the interpreter that what kind of values we can store into a variable and how much amount of memory will be consumed to store the data and the operations it can perform

# %%
input_value = input("Enter your in numbers: ")
print("Type of input value", input_value, type(input_value))

# %%
print("28" + 28)

# %% [markdown]
# ## Different Types of Data Types
# - int ( 1, -1, 10)
# - str ( "Abc", "123", "ab12cd34")
# - bool ( True / False)
# - float ( 1.0 , 4.58, 88.99)

# %%
print("hello world")
# Out:
# Running cells with '.venv (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/arunk/OneDrive/Desktop/Learning/complete-genai/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
