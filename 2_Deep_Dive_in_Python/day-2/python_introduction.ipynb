# %% [markdown]
# # What is Python Language
# ---

# %% [markdown]
# ### Python is a type of programming language whichhwe can use for communicating with computers or technology

# %% [markdown]
# ---
# ## Syntax for Python language

# %% [markdown]
# Syntax refers to the set of rules that defines the combination of symbols that are consider to be correctly structured programs in a language.

# %% [markdown]
# # Semantics of Python Language

# %% [markdown]
# Semantics of Python language refers tot he meaning or interpreations of symbols, characters and commands in a language. It is about what the code is supposed to do when it run.

# %% [markdown]
# ---
# # Python Syntax Rules
# - Python is case-sensitive

# %%
name = 'Amit'
Name = 'Amit'
name==Name
# Out:
# True

# %%
name= "Amit"
Name= "amit"
name == Name
# Out:
# False

# %% [markdown]
# ---
# # Indentation in Python

# %% [markdown]
# - In other programming language, we use {} for grouping of statements
# - but in Python, we use indentation for proper grouping of statements as the proper arrangement of
# - statements with proper spacing in the statements within a block.

# %%
age = int(input("Enter your age: "))
if age > 18:
    print('you are eligible for driving')
else:
    print('you are minor')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 age = int(input("Enter your age: "))
#       2 if age > 18:
#       3     print('you are eligible for driving')
#       4 else:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
age = int(input("Enter your age: "))
if age > 18:
print('you are eligible for driving')
else:
    print('you are minor')
# Out:
#   Cell In[4], line 3
#     print('you are eligible for driving')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
1+2+3+4+5+6
# Out:
# 21

# %% [markdown]
# ## Line Continuation --> We can use Backslash ( \ ) for continuing the statement on the next line

# %% [markdown]
# ---
#
# # Multiple Statements in a Single Line in Python

# %%
a = 5;
b = 6;
# Out:
# The kernel failed to start as the Python Environment 'Python 3.12.10' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
# multiple variable using semicolon
a = 5 ; b = 6 ;
