# %% [markdown]
# ---
# # `Matrix Plots`
# ---

# %%
# Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
student_data = pd.read_csv("Datasets/student_depression_dataset.csv") 
chocolate_data = pd.read_csv("Datasets/Chocolate Sales.csv") 
tips = sns.load_dataset('tips')
gaps = px.data.gapminder()

# %% [markdown]
# ## `Matrix Plot in Seaborn`
#
# A Matrix Plot is a visualization used to represent data stored in a matrix (rows × columns) using colors.
#
# Instead of bars, lines, or points, matrix plots use color intensity to represent values.

# %% [markdown]
# ## Simple Definition
#
# A Matrix Plot visualizes values in a two-dimensional matrix using colors, making it easy to identify patterns, correlations, missing values, and clusters.
#
# ---

# %% [markdown]
# ## `Why Do We Use Matrix Plots?`
#
# Suppose we have the following data:
#
# | Student | Math | Science | English |
# | ------- | ---- | ------- | ------- |
# | A       | 90   | 85      | 80      |
# | B       | 70   | 75      | 65      |
# | C       | 95   | 92      | 88      |
#
#
# Looking at numbers is difficult.
#
# A matrix plot converts numbers into colors:
#
# ```code
#        Math  Sci  Eng
# A      ████ ███  ██
# B      ██   ██   █
# C      ████ ████ ███
# ```
#
# Darker color = Higher value
#
# Lighter color = Lower value
#
# Note: In Matrix Plot, only Axes Level Functions, not having Figure Level Functions
#
# ---

# %% [markdown]
# ## `Matrix Plot Functions in Seaborn`
#
# Seaborn mainly provides:
#
# ### - `heatmap()`
# ### - `clustermap()`
#
# These are collectively called Matrix Plots.

# %% [markdown]
# ---

# %% [markdown]
# ## `Heatmap`
# ---
#
# - Definition: A **Heatmap** is a matrix plot that represents values using different colors.
# - Higher values are shown with darker/intense colors and lower values with lighter colors.
# - Heatmap uses color shades to show the size of Number in a Matrix 2D table
# - In every classification Machine Learning Problem Statement, we use the Heatmap
# - For coming up an Heatmpa or an Matrix which we can convert into an Heatmap, we create a Pivot Table and then that Pivot Table, we can use to create an Heatmap
#
#
# - pivot() --> index, columns, values --> gap.pivot(index='', columns = '', values = '' )
#
# ### Why Use Heatmap?
# - Visualize correlation between numerical features
# - Detect patterns and trends
# - Identify missing values
# - Easy representation of matrix data
#
# ### Syntax: `sns.heatmap(data)`
#
# ### Correlation Heatmap
#
# ```code
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# corr = df.corr(numeric_only=True)
#
# sns.heatmap(corr)
# plt.show()
# ```
#
# ### Important Parameters
#
# ```code
# sns.heatmap(
#     corr,
#     annot=True,      # Show values inside cells --> shows number as well for the rectangular grid
#     cmap="coolwarm", # Color palette --> special styling for the heatmap itself
#     linewidths=1,    # Border width
#     cbar=True        # Show color bar
# )
# ```
#
# ### Common Color Maps --> values for cmap
#
# ```code
# "coolwarm"
# "viridis"
# "Blues"
# "YlGnBu"
# "rocket"
# ```
#
# ### Missing Value Heatmap
#
# ```code
# sns.heatmap(df.isnull())
# plt.show()
# ```
#
# ### Applications
# - Correlation Analysis
# - Missing Value Detection
# - Feature Selection
# - Data Pattern Analysis

# %%
gaps.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
dt = gaps.pivot(index='country', columns='year', values= 'lifeExp')

# %%
dt
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
sns.heatmap(data = dt)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# heatmap for only europs countries
gaps [gaps['continent'] == 'Europe']
# Out:
#              country continent  year  lifeExp       pop     gdpPercap  \
# 12           Albania    Europe  1952   55.230   1282697   1601.056136
# 13           Albania    Europe  1957   59.280   1476505   1942.284244
# 14           Albania    Europe  1962   64.820   1728137   2312.888958
# 15           Albania    Europe  1967   66.220   1984060   2760.196931
# 16           Albania    Europe  1972   67.690   2263554   3313.422188
# ...              ...       ...   ...      ...       ...           ...
# 1603  United Kingdom    Europe  1987   75.007  56981620  21664.787670
# 1604  United Kingdom    Europe  1992   76.420  57866349  22705.092540
# 1605  United Kingdom    Europe  1997   77.218  58808266  26074.531360
# 1606  United Kingdom    Europe  2002   78.471  59912431  29478.999190
# 1607  United Kingdom    Europe  2007   79.425  60776238  33203.261280
#
#      iso_alpha  iso_num
# 12         ALB        8
# 13         ALB        8
# 14         ALB        8
# 15         ALB        8
# ...

# %%
dt = gaps [gaps['continent'] == 'Europe'].pivot(index='country', columns='year', values= 'lifeExp')

# %%
sns.heatmap(dt)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# annotatoins = true
sns.heatmap(data = dt, annot=True)
plt.show()

# %%
# annotatoins = true
plt.figure(figsize=(15,15))
sns.heatmap(data = dt, annot=True)
plt.show()

# %%
# styling / theme
plt.figure(figsize=(15,15))
sns.heatmap(data = dt, annot=True, cmap='coolwarm')
plt.show()

# %%
# line width 
plt.figure(figsize=(15,15))
sns.heatmap(data = dt, annot=True, cmap='Blues', linewidths=0.5)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Clustermap
# ---
# - A **Clustermap** is an advanced heatmap that automatically groups similar rows and columns using hierarchical clustering.
# - combination of Both HeatMpa and Automatic Grouping using clustering
# - Groups the similar rows and similar columns using Machine Learning Algorithm internally ( heirarchial Cluster Technique - to cluser the Rows Together and it uses Algomerative Heirarchial clustering)
# - Helps in Finding the hidden patterns in your data.
#
# ### Why Use Clustermap?
# - Find hidden patterns
# - Group similar features
# - Identify clusters in data
# - Useful in Machine Learning and Data Analysis
#
# ### Syntax: `sns.clustermap(data)`
#
# ### Example
#
# ```code
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# corr = df.corr(numeric_only=True)
#
# sns.clustermap(corr)
# plt.show()
# ```
#
# ### Important Parameters
#
# ```code
# sns.clustermap(
#     corr,
#     annot=True,
#     cmap="coolwarm",
#     figsize=(8,6)
# )
# ```
#
# ### Difference Between Heatmap and Clustermap
#
# | Heatmap | Clustermap |
# |----------|------------|
# | Shows matrix values using colors | Shows matrix values + clustering |
# | No grouping | Automatic grouping |
# | Simpler | More advanced |
# | Correlation visualization | Pattern and cluster detection |
#
# ### Applications
# - Feature Clustering
# - Pattern Recognition
# - Gene Expression Analysis
# - Similarity Detection
# - Machine Learning EDA

# %%
# different species of flowers
iris_data = px.data.iris()

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
# pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.clustermap(iris_data.iloc[:,[0,1,2,3,4]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.clustermap(iris_data.iloc[:,[0,1,2,3,4]])
#
# File c:\Users\arunk\anaconda3\envs\genai_env\Lib\site-packages\seaborn\matrix.py:1258, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1250     raise RuntimeError("clustermap requires scipy to be available")
#    1252 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1253                       row_colors=row_colors, col_colors=col_colors,
#    1254                       z_score=z_score, standard_scale=standard_scale,
#    1255                       mask=mask, dendrogram_ratio=dendrogram_ratio,
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### `What is the difference between Heatmap and Clustermap?`
#
# Heatmap visualizes matrix values using colors, while Clustermap extends a heatmap by automatically clustering similar rows and columns, making it easier to identify groups and hidden patterns in the data.
