# %% [markdown]
# ---
# # `Decoders working in Transformer`
# ---

# %% [markdown]
# - Purpose of Decoders is Next Word Prediction based on given Input Data passed to the encoders
# - eg. Hi, How are you?
# - Encoder - responsible for output contextual embeddings and passed to decoders also
# - Decoder - responsible for Next Word Prediction
#
# With Decoders, There are 2 Phases
# 1. Training
# - we let the decoder predict, the next word using forward propagation
# - Backpropagation - we make decoder predict more accurate next words and here we are already having actual output, so calculation loss becomes easier based on prediction and this happens at the time Training Phase of the decoders
# -
#
# 2. Inferencing
# - we provider input to decoder based on training,
# - Input : Hello how are you?
# - Decoder based on its training generate : I ist prediction
#
# In this way, Decoder keeps on generating the Next word prediction until we reach end of string process keep repeating
#
# Here at the Output Generation, we use **Linear + Softmax** Activation Function. So because of which linear have different probabilities assigned to different possible outcomes
#
# for example
# - Hello how are you --> Decoder
# - Different probabilites are assigned using Linear + Softmax --> Decides which Next Prediction to go with based on probability at the highest
# - we can even change these outcomes using temperature for creativity

# %% [markdown]
# ---
# ---
# # `Detailed Notes`
# ---
# ---

# %% [markdown]
# # Decoder Working in Transformers
#
# ## Definition
#
# The **Decoder** is the component of a Transformer responsible for **generating the output sequence one token at a time**.
#
# Its primary task is **Next Token Prediction**. Based on the input and the tokens generated so far, the decoder predicts the most probable next token until the complete output is generated.
#
# > **Definition:**
# > A **Transformer Decoder** generates text by repeatedly predicting the next token using the previously generated tokens and the contextual information learned during training.
#
# ---
#
# # Purpose of the Decoder
#
# The decoder's main responsibility is:
#
# * Predict the next token.
# * Generate complete sentences token by token.
# * Continue generation until an **End-of-Sequence (EOS)** token is produced.
#
# ### Example
#
# **Input**
#
# ```text
# Hi, How are you?
# ```
#
# **Possible Output**
#
# ```text
# I am doing well, thank you!
# ```
#
# The decoder does **not** generate the entire sentence at once.
#
# Instead, it predicts:
#
# ```text
# I
# ↓
#
# am
# ↓
#
# doing
# ↓
#
# well
# ↓
#
# ,
# ↓
#
# thank
# ↓
#
# you
# ↓
#
# !
# ↓
#
# <EOS>
# ```
#
# ---
#
# # Encoder vs Decoder
#
# | Encoder                        | Decoder                                          |
# | ------------------------------ | ------------------------------------------------ |
# | Understands the input sequence | Generates the output sequence                    |
# | Produces contextual embeddings | Predicts the next token                          |
# | Learns input context           | Uses context + previous outputs to generate text |
#
# > **Note:**
# > In an **Encoder-Decoder Transformer** (like the original Transformer used for translation), the encoder provides contextual embeddings to the decoder.
# > In **decoder-only models** such as GPT, there is **no encoder**. The decoder generates text using only the prompt and previously generated tokens.
#
# ---
#
# # Decoder Workflow
#
# ```text
# Input Text
#       ↓
# Tokenizer
#       ↓
# Embeddings
#       ↓
# Positional Encoding
#       ↓
# Masked Multi-Head Self-Attention
#       ↓
# Feed Forward Network
#       ↓
# Linear Layer
#       ↓
# Softmax
#       ↓
# Next Token Prediction
# ```
#
# ---
#
# # Two Phases of the Decoder
#
# The decoder operates differently during:
#
# 1. **Training**
# 2. **Inference (Generation)**
#
# ---
#
# # Phase 1: Training
#
# During training, the model already knows the **correct output sentence**.
#
# This allows it to compare its predictions with the actual answer and improve itself.
#
# ---
#
# ## Example
#
# Target sentence:
#
# ```text
# I love AI
# ```
#
# The decoder learns using shifted inputs.
#
# | Decoder Input       | Target Output |
# | ------------------- | ------------- |
# | `<START>`           | I             |
# | `<START> I`         | love          |
# | `<START> I love`    | AI            |
# | `<START> I love AI` | `<EOS>`       |
#
# At every step, the decoder predicts the next token.
#
# ---
#
# ## Step 1: Forward Propagation
#
# The decoder predicts the next token.
#
# Example:
#
# Input:
#
# ```text
# <START> I
# ```
#
# Prediction:
#
# ```text
# like
# ```
#
# Actual Answer:
#
# ```text
# love
# ```
#
# The prediction is incorrect.
#
# ---
#
# ## Step 2: Loss Calculation
#
# The prediction is compared with the actual target.
#
# Example:
#
# Prediction:
#
# ```text
# like
# ```
#
# Actual:
#
# ```text
# love
# ```
#
# The model computes a **loss** (prediction error).
#
# Common loss function:
#
# * Cross-Entropy Loss
#
# Higher error → Higher loss.
#
# ---
#
# ## Step 3: Backpropagation
#
# The loss is propagated backward.
#
# The model updates:
#
# * Attention weights
# * Feed Forward weights
# * Embedding weights
# * Linear layer weights
#
# The goal is to make future predictions more accurate.
#
# ---
#
# ## Training Loop
#
# ```text
# Input
#
# ↓
#
# Prediction
#
# ↓
#
# Calculate Loss
#
# ↓
#
# Backpropagation
#
# ↓
#
# Update Weights
#
# ↓
#
# Repeat
# ```
#
# This process repeats millions or billions of times during training.
#
# ---
#
# # Why Is Training Easier?
#
# During training:
#
# * The correct output already exists.
# * The model always knows the expected next token.
# * Computing the error is straightforward.
#
# This approach is commonly called **Teacher Forcing**, where the decoder is fed the correct previous token instead of its own prediction.
#
# > **Interview Point:** Teacher forcing speeds up training and stabilizes learning.
#
# ---
#
# # Phase 2: Inference (Text Generation)
#
# During inference, the correct answer is **not available**.
#
# The decoder must generate text on its own.
#
# ---
#
# ## Example
#
# User Input:
#
# ```text
# Hello, how are you?
# ```
#
# ---
#
# ### Step 1
#
# Prompt:
#
# ```text
# Hello, how are you?
# ```
#
# ↓
#
# Decoder predicts:
#
# ```text
# I
# ```
#
# ---
#
# ### Step 2
#
# New Input:
#
# ```text
# Hello, how are you?
#
# I
# ```
#
# ↓
#
# Decoder predicts:
#
# ```text
# am
# ```
#
# ---
#
# ### Step 3
#
# Input:
#
# ```text
# Hello, how are you?
#
# I am
# ```
#
# ↓
#
# Prediction:
#
# ```text
# doing
# ```
#
# ---
#
# The process continues:
#
# ```text
# doing
#
# ↓
#
# well
#
# ↓
#
# ,
#
# ↓
#
# thank
#
# ↓
#
# you
#
# ↓
#
# !
#
# ↓
#
# <EOS>
# ```
#
# The decoder stops when it predicts the **End-of-Sequence (EOS)** token or reaches the maximum generation length.
#
# ---
#
# # Complete Inference Flow
#
# ```text
# Prompt
#
# ↓
#
# Predict Next Token
#
# ↓
#
# Append Token
#
# ↓
#
# Predict Again
#
# ↓
#
# Append Again
#
# ↓
#
# Repeat
#
# ↓
#
# <EOS>
#
# ↓
#
# Stop
# ```
#
# ---
#
# # How Does the Decoder Choose the Next Token?
#
# The decoder does not directly output a word.
#
# Instead, it produces a **score (logit)** for every token in the vocabulary.
#
# Suppose the vocabulary contains:
#
# ```text
# I
# You
# We
# They
# He
# ```
#
# The Linear layer generates logits.
#
# Example:
#
# | Token | Logit |
# | ----- | ----: |
# | I     |   5.4 |
# | You   |   2.1 |
# | We    |   1.3 |
# | They  |   0.9 |
# | He    |   1.8 |
#
# These logits are converted into probabilities using the **Softmax** function.
#
# ---
#
# # Linear Layer + Softmax
#
# The final layers of the decoder are:
#
# ```text
# Decoder Output
#
# ↓
#
# Linear Layer
#
# ↓
#
# Logits
#
# ↓
#
# Softmax
#
# ↓
#
# Probability Distribution
#
# ↓
#
# Next Token
# ```
#
# ---
#
# ## Example
#
# After Softmax:
#
# | Token | Probability |
# | ----- | ----------: |
# | I     |    **0.73** |
# | You   |        0.12 |
# | We    |        0.08 |
# | They  |        0.04 |
# | He    |        0.03 |
#
# The model usually selects the token with the highest probability.
#
# Prediction:
#
# ```text
# I
# ```
#
# ---
#
# # Temperature in Text Generation
#
# Sometimes we don't always want the highest-probability token.
#
# We can control creativity using a parameter called **Temperature**.
#
# ### Low Temperature (e.g., 0.2)
#
# * Less randomness.
# * More predictable.
# * More factual.
# * Best for coding and question answering.
#
# Example:
#
# ```text
# Probability
#
# I → 95%
#
# You → 3%
#
# We → 2%
# ```
#
# The model almost always chooses **I**.
#
# ---
#
# ### High Temperature (e.g., 1.2)
#
# * More randomness.
# * More creativity.
# * More diverse responses.
# * Better for storytelling and brainstorming.
#
# The model may occasionally choose lower-probability words to produce more varied outputs.
#
# > **Interview Point:** Temperature changes the probability distribution before sampling, influencing how deterministic or creative the generated text is.
#
# ---
#
# # Real-World Analogy
#
# Imagine typing on your smartphone.
#
# You type:
#
# ```text
# Happy
# ```
#
# The keyboard suggests:
#
# | Word     | Probability |
# | -------- | ----------: |
# | Birthday |         85% |
# | Morning  |         10% |
# | Journey  |          5% |
#
# Your keyboard predicts the most likely next word.
#
# A Transformer decoder works in a similar way—but on a much larger vocabulary and using deep contextual understanding.
#
# ---
#
# # Decoder Generation Process
#
# ```text
# User Prompt
#
# ↓
#
# Decoder
#
# ↓
#
# Linear Layer
#
# ↓
#
# Softmax
#
# ↓
#
# Next Token
#
# ↓
#
# Append Token
#
# ↓
#
# Decoder
#
# ↓
#
# Repeat
#
# ↓
#
# <EOS>
# ```
#
# ---
#
# # Interview Tips
#
# > **Remember:**
# >
# > * The decoder performs **next-token prediction**.
# > * During **training**, the correct output is available, enabling loss computation and backpropagation.
# > * During **inference**, the decoder generates one token at a time using its own previous outputs.
# > * The **Linear layer** converts hidden states into logits.
# > * **Softmax** converts logits into probabilities.
# > * **Temperature** controls the randomness and creativity of generation.
# > * In GPT-style models, the decoder uses **masked self-attention**, ensuring it cannot look at future tokens during generation.
#
# ---
#
# # Key Takeaways
#
# * The decoder generates text one token at a time.
# * It has two operating phases: **Training** and **Inference**.
# * During training, it learns by comparing predictions with the correct output and updating its parameters.
# * During inference, it predicts the next token repeatedly until an **EOS** token is generated.
# * The Linear layer produces logits, and Softmax converts them into probabilities.
# * Temperature influences how deterministic or creative the output becomes.
#
# ---
#
# # Interview Questions & Answers
#
# ## Beginner Questions
#
# ### 1. What is the primary role of the Transformer decoder?
#
# **Answer:**
# To generate the output sequence by predicting one token at a time based on the input context and previously generated tokens.
#
# ---
#
# ### 2. What are the two phases of decoder operation?
#
# **Answer:**
#
# 1. Training
# 2. Inference (Text Generation)
#
# ---
#
# ### 3. What happens during training?
#
# **Answer:**
# The decoder predicts the next token, compares it with the correct target, computes the loss, and updates its parameters using backpropagation.
#
# ---
#
# ### 4. What happens during inference?
#
# **Answer:**
# The decoder generates one token at a time, appends it to the sequence, and continues until an EOS token or maximum sequence length is reached.
#
# ---
#
# ### 5. Why is Softmax used?
#
# **Answer:**
# Softmax converts the decoder's output logits into a probability distribution over the vocabulary, allowing the model to select or sample the next token.
#
# ---
#
# ## Intermediate Questions
#
# ### 1. Why is training easier than inference?
#
# **Answer:**
# During training, the correct next token is already known (teacher forcing), making it easy to compute the loss and update the model. During inference, the model must rely solely on its own predictions.
#
# ---
#
# ### 2. What is Teacher Forcing?
#
# **Answer:**
# Teacher forcing is a training technique where the decoder receives the correct previous token as input instead of its own predicted token, leading to faster and more stable learning.
#
# ---
#
# ### 3. What is the role of the Linear layer?
#
# **Answer:**
# It maps the decoder's hidden representation to a vector of logits, with one score for each token in the vocabulary.
#
# ---
#
# ### 4. How does temperature affect generation?
#
# **Answer:**
# Lower temperatures produce more deterministic and factual outputs, while higher temperatures increase randomness and creativity by flattening the probability distribution.
#
# ---
#
# ## Scenario-Based Questions
#
# ### 1. During inference, the decoder predicts the wrong first token. What happens next?
#
# **Answer:**
# Since the decoder uses its previously generated tokens as input during inference, an incorrect early prediction can influence subsequent predictions and potentially propagate errors throughout the generated sequence.
#
# ---
#
# ### 2. A chatbot should always provide precise and consistent answers. Would you use a high or low temperature?
#
# **Answer:**
# A **low temperature** is preferable because it favors the highest-probability tokens, resulting in more consistent, accurate, and deterministic responses.
#
# ---
#
# # 30-Second Revision
#
# * Decoder predicts **one token at a time**.
# * Two phases: **Training** and **Inference**.
# * Training uses **teacher forcing**, computes **loss**, and performs **backpropagation**.
# * Inference generates tokens sequentially until **EOS**.
# * **Linear layer** → logits.
# * **Softmax** → probabilities.
# * **Temperature** controls creativity.
#
# ---
#
# # 2-Minute Revision
#
# * The Transformer decoder is responsible for next-token prediction.
# * During training, it receives the correct previous tokens, predicts the next token, computes the loss, and updates its parameters through backpropagation.
# * During inference, it generates text autoregressively by using its own previous outputs as input.
# * The decoder's hidden states are transformed into logits by a Linear layer, then converted into probabilities by Softmax.
# * The temperature parameter adjusts the randomness of token selection, balancing factuality and creativity.

# %% [markdown]
# ---
# ---
# # `Detailed Notes 2`
# ---
# ---

# %% [markdown]
# # Encoder, Decoder, Training, and Inferencing in Transformers
#
# To understand **Large Language Models (LLMs)**, you must understand four fundamental concepts:
#
# 1. **Encoder**
# 2. **Decoder**
# 3. **Training**
# 4. **Inference**
#
# ---
#
# # Big Picture
#
# ```text
#                   Transformer
#
#         -----------------------------
#         |                           |
#         |                           |
#     Encoder                  Decoder
#         |                           |
#         -----------------------------
#                   |
#             Final Output
# ```
#
# Different Transformer models use different parts of this architecture:
#
# | Model                      | Uses              |
# | -------------------------- | ----------------- |
# | BERT                       | Encoder Only      |
# | GPT, LLaMA, Gemma, Mistral | Decoder Only      |
# | T5, BART                   | Encoder + Decoder |
#
# ---
#
# # What is an Encoder?
#
# An **Encoder** reads the **entire input sequence** and converts it into a rich contextual representation.
#
# It focuses on **understanding** the input.
#
# It does **not generate text**.
#
# ---
#
# ## Example
#
# Input:
#
# ```text
# I love Deep Learning
# ```
#
# The encoder processes all words **simultaneously**.
#
# ```text
# I
# ↓
#
# love
# ↓
#
# Deep
# ↓
#
# Learning
# ```
#
# Each word attends to every other word.
#
# Output:
#
# ```text
# Contextual Representation
#
# ↓
#
# I'
#
# love'
#
# Deep'
#
# Learning'
# ```
#
# These are not ordinary embeddings anymore—they are **context-aware embeddings**.
#
# ---
#
# # Encoder Architecture
#
# Each Encoder block contains:
#
# ```text
# Input
#    │
#    ▼
# Multi-Head Attention
#    │
# Residual + LayerNorm
#    │
#    ▼
# Feed Forward Network
#    │
# Residual + LayerNorm
#    │
# Output
# ```
#
# This block is repeated multiple times.
#
# Example:
#
# ```text
# Encoder
#
# ↓
#
# Layer 1
#
# ↓
#
# Layer 2
#
# ↓
#
# Layer 3
#
# ↓
#
# ...
#
# ↓
#
# Layer 12
# ```
#
# (BERT Base has **12 encoder layers**.)
#
# ---
#
# # Characteristics of Encoder
#
# * Reads the complete sentence.
# * Uses **Bidirectional Self-Attention**.
# * Every word can attend to every other word.
# * Produces contextual embeddings.
# * Excellent for language understanding.
#
# ---
#
# # Applications
#
# Encoders are commonly used for:
#
# * Text Classification
# * Sentiment Analysis
# * Named Entity Recognition (NER)
# * Question Answering
# * Semantic Search
# * Document Retrieval
#
# ---
#
# # What is a Decoder?
#
# A **Decoder** generates text **one token at a time**.
#
# It focuses on **text generation** rather than understanding.
#
# Unlike an encoder, it **cannot look at future tokens** during generation.
#
# ---
#
# ## Example
#
# Prompt:
#
# ```text
# Artificial Intelligence is
# ```
#
# The decoder predicts:
#
# ```text
# transforming
# ```
#
# Now the input becomes:
#
# ```text
# Artificial Intelligence is transforming
# ```
#
# Then it predicts the next token:
#
# ```text
# the
# ```
#
# Then:
#
# ```text
# world
# ```
#
# Generation continues until an end-of-sequence token is produced.
#
# ---
#
# # Decoder Architecture
#
# ```text
# Input
#
# ↓
#
# Masked Multi-Head Attention
#
# ↓
#
# Residual + LayerNorm
#
# ↓
#
# Feed Forward Network
#
# ↓
#
# Residual + LayerNorm
#
# ↓
#
# Output
# ```
#
# This block is repeated many times.
#
# Example:
#
# ```text
# Decoder
#
# ↓
#
# Layer 1
#
# ↓
#
# Layer 2
#
# ↓
#
# ...
#
# ↓
#
# Layer 32
# ```
#
# ---
#
# # Why Masked Attention?
#
# Suppose the sentence is:
#
# ```text
# I love AI
# ```
#
# While predicting:
#
# ```text
# love
# ```
#
# The model must **not** see:
#
# ```text
# AI
# ```
#
# Otherwise, it would "cheat" during next-token prediction.
#
# A **causal mask** prevents attention to future positions.
#
# ---
#
# ## Example
#
# Sentence:
#
# ```text
# I love AI
# ```
#
# When predicting:
#
# ```text
# love
# ```
#
# The decoder can attend to:
#
# ```text
# I
# ```
#
# but **not**:
#
# ```text
# AI
# ```
#
# ---
#
# # Decoder Attention Matrix
#
# Without masking:
#
# ```text
#       I  love  AI
#
# I     ✓   ✓    ✓
#
# love  ✓   ✓    ✓
#
# AI    ✓   ✓    ✓
# ```
#
# With causal masking:
#
# ```text
#       I  love  AI
#
# I     ✓   ✗    ✗
#
# love  ✓   ✓    ✗
#
# AI    ✓   ✓    ✓
# ```
#
# Future tokens are hidden.
#
# ---
#
# # Characteristics of Decoder
#
# * Generates one token at a time.
# * Uses **Masked Self-Attention**.
# * Cannot attend to future tokens.
# * Designed for autoregressive generation.
#
# ---
#
# # Applications
#
# Decoder-only models are commonly used for:
#
# * ChatGPT
# * Text Generation
# * Code Generation
# * Story Writing
# * Translation (decoder side)
# * Summarization
# * Conversational AI
#
# ---
#
# # Encoder vs Decoder
#
# | Feature               | Encoder          | Decoder         |
# | --------------------- | ---------------- | --------------- |
# | Purpose               | Understand Input | Generate Output |
# | Attention             | Bidirectional    | Causal (Masked) |
# | Can See Future Tokens | Yes              | No              |
# | Text Generation       | No               | Yes             |
# | Example Models        | BERT             | GPT, LLaMA      |
#
# ---
#
# # Encoder-Decoder Architecture
#
# Models like **T5** and **BART** use both.
#
# Example:
#
# ```text
# English
#
# ↓
#
# Encoder
#
# ↓
#
# Context Representation
#
# ↓
#
# Decoder
#
# ↓
#
# French
# ```
#
# Example:
#
# ```text
# Translate:
#
# I love AI
#
# ↓
#
# J'aime l'IA
# ```
#
# The encoder understands the source sentence.
#
# The decoder generates the translated sentence.
#
# ---
#
# # Complete Architecture
#
# ```text
# Input Sentence
#
# ↓
#
# Encoder
#
# ↓
#
# Context Representation
#
# ↓
#
# Decoder
#
# ↓
#
# Generated Output
# ```
#
# ---
#
# # Training
#
# ## What is Training?
#
# Training is the process in which the model **learns patterns** from massive datasets by adjusting its parameters.
#
# During training:
#
# * Predictions are made.
# * Errors are measured.
# * Parameters are updated using backpropagation.
#
# ---
#
# # Training Pipeline
#
# ```text
# Dataset
#
# ↓
#
# Tokenizer
#
# ↓
#
# Embeddings
#
# ↓
#
# Transformer
#
# ↓
#
# Prediction
#
# ↓
#
# Loss
#
# ↓
#
# Backpropagation
#
# ↓
#
# Update Weights
#
# ↓
#
# Repeat
# ```
#
# ---
#
# # Example
#
# Sentence:
#
# ```text
# The capital of France is Paris.
# ```
#
# Training example:
#
# Input:
#
# ```text
# The capital of France is
# ```
#
# Target:
#
# ```text
# Paris
# ```
#
# The model predicts:
#
# ```text
# London
# ```
#
# Loss:
#
# High
#
# ↓
#
# Update Parameters
#
# ↓
#
# Predict Again
#
# ↓
#
# Eventually
#
# ↓
#
# Paris
#
# ````
#
# This process repeats across billions of examples.
#
# ---
#
# # Loss Function
#
# For language modeling:
#
# ```text
# Cross Entropy Loss
# ````
#
# The objective is to maximize the probability of the correct next token.
#
# ---
#
# # Optimizer
#
# Modern LLMs typically use:
#
# ```text
# AdamW
# ```
#
# instead of the original Adam optimizer.
#
# ---
#
# # Backpropagation
#
# ```text
# Prediction
#
# ↓
#
# Loss
#
# ↓
#
# Gradient Calculation
#
# ↓
#
# Update Parameters
#
# ↓
#
# Better Prediction
# ```
#
# Every parameter is updated:
#
# * Embeddings
# * Attention matrices
# * Feed Forward weights
# * LayerNorm parameters
#
# ---
#
# # Training Example
#
# Prompt:
#
# ```text
# Artificial Intelligence is
# ```
#
# Correct next token:
#
# ```text
# transforming
# ```
#
# Prediction:
#
# ```text
# amazing
# ```
#
# Loss:
#
# ```text
# High
# ```
#
# Backpropagation updates the model so that **transforming** receives a higher probability in similar contexts.
#
# ---
#
# # What is Inferencing?
#
# Inference is the process of **using a trained model** to generate predictions.
#
# No learning occurs.
#
# Weights remain unchanged.
#
# ---
#
# # Inference Pipeline
#
# ```text
# User Prompt
#
# ↓
#
# Tokenizer
#
# ↓
#
# Embeddings
#
# ↓
#
# Transformer
#
# ↓
#
# Next Token
#
# ↓
#
# Append Token
#
# ↓
#
# Repeat
#
# ↓
#
# Final Response
# ```
#
# ---
#
# # Example
#
# Prompt:
#
# ```text
# The capital of India is
# ```
#
# Model predicts:
#
# ```text
# New
# ```
#
# Now input becomes:
#
# ```text
# The capital of India is New
# ```
#
# Next prediction:
#
# ```text
# Delhi
# ```
#
# Now:
#
# ```text
# The capital of India is New Delhi
# ```
#
# Generation continues until an end-of-sequence token or another stopping criterion is reached.
#
# ---
#
# # Training vs Inference
#
# | Feature           | Training | Inference            |
# | ----------------- | -------- | -------------------- |
# | Dataset Required  | Yes      | No                   |
# | Backpropagation   | Yes      | No                   |
# | Parameter Updates | Yes      | No                   |
# | Loss Computation  | Yes      | No                   |
# | Optimizer         | Yes      | No                   |
# | Objective         | Learn    | Generate Predictions |
#
# ---
#
# # Complete Workflow
#
# ```text
#                   TRAINING
#
# Dataset
#
# ↓
#
# Tokenizer
#
# ↓
#
# Embeddings
#
# ↓
#
# Transformer
#
# ↓
#
# Prediction
#
# ↓
#
# Loss
#
# ↓
#
# Backpropagation
#
# ↓
#
# Update Weights
#
# ↓
#
# Repeat
#
# ----------------------------------------
#
#                  INFERENCE
#
# User Prompt
#
# ↓
#
# Tokenizer
#
# ↓
#
# Embeddings
#
# ↓
#
# Transformer
#
# ↓
#
# Next Token
#
# ↓
#
# Append Token
#
# ↓
#
# Repeat Until Complete
# ```
#
# ---
#
# # BERT vs GPT vs T5
#
# | Model | Architecture      | Main Purpose                                      |
# | ----- | ----------------- | ------------------------------------------------- |
# | BERT  | Encoder Only      | Understanding (classification, retrieval, QA)     |
# | GPT   | Decoder Only      | Text Generation                                   |
# | T5    | Encoder + Decoder | Translation, Summarization, General Seq2Seq Tasks |
#
# ---
#
# # Complete Transformer Family
#
# ```text
#                  Transformer
#
#                     │
#
#         ----------------------------
#
#         │                          │
#
#      Encoder                  Decoder
#
#         │                          │
#
#      BERT                     GPT
#
#         │                          │
#
#      Understanding         Text Generation
#
#         │
#
#         └──────────────┐
#
#                        ▼
#
#                  Encoder + Decoder
#
#                        │
#
#                   T5 / BART
#
#                        │
#
#       Translation, Summarization
# ```
#
# ---
#
# # Interview Summary
#
# > A **Transformer Encoder** is designed to understand the entire input sequence using **bidirectional self-attention**, making it ideal for tasks such as text classification and question answering. A **Transformer Decoder** generates text one token at a time using **causal (masked) self-attention**, ensuring that future tokens are not visible during prediction. During **training**, the model learns by predicting target tokens, computing a loss (typically cross-entropy), and updating its parameters through backpropagation with an optimizer such as AdamW. During **inference**, the trained model generates text autoregressively by repeatedly predicting the next token without updating its parameters. Encoder-only models include **BERT**, decoder-only models include **GPT** and **LLaMA**, while **T5** and **BART** use both an encoder and a decoder for sequence-to-sequence tasks.
