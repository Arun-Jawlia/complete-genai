# %% [markdown]
# ---
# # `Feature Engineering with Modelling and Deployment`
# ---

# %% [markdown]
# ## Feature Engineering and Modelling for Rule Bases Vs Generateive AI Chatbots with Deployment in Further Pipeline

# %% [markdown]
# Vector Embedding: knowledge matter alot in building genai applications
# LLM -- Chatbot ( NLP) -- GenAI
# HuggingFace, Models, Gemini Ai, Mistral, Ollama
#
#
# GPT --> Generative Pretrained Transformer --> foundation Model --> Single task ( Predict Next Word) --> Fine Tune --> Multiple Task --> Question Answering Model --> ChatGPT
#
# NLP --> Simple question answering
#
# Chatbots --> NLU and NLG Capabilites --> NLU  ( understand ) --> Human Text --> Numbers format --> Feature Enginnering ( understand the text data )
#
# Vector Embeddings: RAG
# Mistral : LLM --> Question Answering Model , if issue with model --> hallucination
# Hallucination: even if these models don't know the answer, still they will provide your with the answer even if it is wrong
#
# Medical book -- medical data -- chatgpt --> geneeating answer baed on the knowledge it gained from the medical book data --> RAG Application
#
# Text --> Medical book text data  --> Numerical format --> Trained my chatgpt model --> Disease -> There is a number --> Something is called Vector Embedding
# for every word, corresponding vector embedding
# collection of vectors --> embedding databases or store vector ---> Vector database
#
# Vector database --> embedding of all of this text data
#
# FAISS : Facebook Aritifical Intelligence Semantic Search
#
# Your Question --> Semantic Search ---> Why need semantic search
#
# can't directly convert text data into number --> we need proper strategy
#
#
# ## Feature Engineering: 2nd Second
# - just because our end model is going to be an ML or DL or mathematical model that's why we need to convert our text data into the numerical format. So we can feed it inside a model
# - Try to build an sentiment analysis --> 50k reviews --> 1 stand for positive and 0 stand for negative  --> to find this data in the ML Model, we will create a new dataset for every row
# - No. of positive word : 5 , no. of negative words: 3 , no. of neutral words: 6 --> Sentiment : 1 --> Text data converted into Numeric data
#
# Semantic Search --> Doctor bot --> Ques: what is diagnosis of cold --> I go for semantic seach in the vector database --> vector embedding of medical book token
#
# In Feature Engineering
# 1. One hot Encoding - ML
#
# - why need of wordofvec --> from bag of world --> bigram/trigam/ngram --> Tffdf --> Word2Vec
# 2. Bag Of Word
# 3. Bigram/Trigram/ Ngram
# 4. TFFDF
# 5. Word2Vec --> Deep Learning Netural Network --> provide semantic meaning
#
# Knowledge
#
# that feature engineering depend upon the Problem statement as well as for the senitment analysis --> different feature engineering or chatbot --> different feature engineering
# Rule baseed chatbot or Generative Chatbot
#
#
#
# ML vs DL
# ML has interpreteability, so we can explain the
#
# Domain knowlege is required fo r everytime - specially ML
# Then only we can have the optimal numeric feature,
# Advantage: we have the idea how we got the idea.
# If my manager want 96% accuracy, I will be able to explain to the manage
# in ML feature engineering interpreteability is their or we know how we got the prediction
#
# In DL feature engineering , dl algo is itself capable to gererate feature from one data, we don't need to go for manual feature engineering along with that no domain knowledge is also required
# 98 % --> manage ask how you get this, How can i answer my manage about this accuracy prediction -> we can't explain
# In FE, interpretebility is not there this is hhe issue in DL , we caa't explain that how got the answer

# %% [markdown]
# What is vector
# what is vector database
# what is vector embeddings
# what is  sematics search  and how it works
